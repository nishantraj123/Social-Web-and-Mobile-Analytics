# %% [markdown]
# <a href="https://colab.research.google.com/github/nishantraj123/Social-Web-and-Mobile-Analytics/blob/main/LAB2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nishant Raj<br>
# R103218183<br>
# 500070098<br>
# CSE_BAO(6th sem)

# %%
# !pip install tweepy
# Out:
# Requirement already satisfied: tweepy in /usr/local/lib/python3.7/dist-packages (3.10.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.3.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy) (2.23.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.2.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (2021.10.8)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)

# %%
import tweepy
import pandas as pd

# %%
consumer_key="CR3oAVsAax9dfOrWGCgcfeTWk"
consumer_secret="B793cNTunhZ3wwMkm8Upi208KmXKkuQD6yGhgC9bJD2yuQBMFQ"
access_token="1493170422762045440-TPsRwULM91tI4Tgl4LJq6c2D7yOWVW"
access_token_secret="QHGanqoBnItORIABJZpPRfPw3klbQZSJ4DsELpdGirdqg"

# %%
auth= tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)
api= tweepy.API(auth)

# %% [markdown]
# # **Tweet from Elon Musk**

# %%
cursor = tweepy.Cursor(api.user_timeline, id='elonmusk', tweet_mode="extended").items(1)

# %%
for i in cursor:
  print(i.full_text)
# Out:
# @wintonARK @pmarca ESG should be deleted if not fixed

# %% [markdown]
# Last 200 tweets from Elon Musk

# %%
number_of_tweets = 200
tweets = []
likes = []
time = []

for i in tweepy.Cursor(api.user_timeline, id='elonmusk', tweet_mode="extended").items(number_of_tweets):
  tweets.append(i.full_text)
  likes.append(i.favorite_count)
  time.append(i.created_at)

# %%
tweets
# Out:
# ['@wintonARK @pmarca ESG should be deleted if not fixed',
#  '@pmarca ESG rules have been twisted to insanity',
#  '@SpaceX Another Starlink launch tomorrow',
#  'You are my favorite hello,\nAnd my hardest goodbye.',
#  '@hiromichimizuno @GailAlfarATX @Tesla @TeslaSolar @japan @vigold @SirineAti @DimaZeniuk @DogeUniversal @cb_doge @elonmuskbooks 真の友人とは、世界が離れていくときに歩みよって来てくれる人のことである。',
#  '@GailAlfarATX @Tesla @TeslaSolar @japan @vigold @SirineAti @DimaZeniuk @DogeUniversal @cb_doge @elonmuskbooks It was an honor',
#  'RT @Tesla: Giga Berlin darf eröffnen 🇩🇪🚘 \n\nCome join the team! https://t.co/OdNeEGt5eB',
#  'Also nuclear is vastly better for global warming than burning hydrocarbons for energy',
#  'For those who (mistakenly) think this is a radiation risk, pick what you think is the worst location. I will travel there &amp; eat locally grown food on TV.\n\nI did this in Japan many years ago, shortly after Fukushima. Radiation risk is much, much lower than most people believe.',
#  'Hopefully, it is now extremely obvious that Europe should restart dormant nuclear power stations and increase power output of existing ones. \n\nThis is *critical* to national and international security.',
#  '@RenataKonkoly @Rainmaker1973 Aquarion and Polaris',
#  'Self-driving car will amplify traffic to insane levels, as you won’t feel the pain of driving yourself',
#  '@MilMileBattery Yeah',
#  '@BLKMDL3 Yup',
#  'Defeating traffic is the ultimate boss battle. Even the most powerful humans in the world cannot defeat traffic.',
#  '@OwenSparks_ @Tesla @POTUS Cool!',
#  '@Rainmaker1973 Polytopia is *way* better imo, if you like strategy games',
#  '@Rainmaker1973 Chess is a simple game. Understandable when all we had to play with were squirrels 🐿 and  rocks\U0001faa8, but now we have computers 💻.',
#  '@PPathole .@boringcompany',
#  '@PPathole 💯',
#  '@drbarnard @GE_Appliances Basic appliances should not connect to the Internet or have significant compute power or they will/are/have obviously be turned into an army of ddos puppets',
#  '@BillyM2k @OfficialABQ Maybe Tesla should make an AI vision device that plugs into these legacy traffic lights. It could just look at traffic &amp; automatically maximize throughput.',
#  '@ICannot_Enough Beta 10.12 probably releases Tuesday in US and Friday in Canada',
#  '@BronxViking718 Terminator Resistance is a good game',
#  'Even some of the best AI software engineers in the world don’t realize how advanced Tesla AI has become',
#  '@ICannot_Enough We are almost at the point where interventions are so rare on city streets that we can turn our attention to applying the code to highways. \n\nNo point in doing so until passing that threshold.',
#  'https://t.co/UrldeBBwEc',
#  '@ChristianWalk1r Increased oil &amp; gas production in the short term is critical or people around the world will be placed under great duress. \n\nThis is not a question of money, it is a question of having enough energy to power civilization.',
#  '@teslaownersSV @SpaceX @NASA To be clear, SpaceX wasn’t given $1.5B – we were given a contract for cargo delivery to &amp; from Space Station that would amount to $1.5B if successful',
#  '@teslaownersSV @SpaceX @NASA My old delta-v mug!',
#  '@OfficialABQ 💯',
#  '@TheBabylonBee Pshaw, how pedestrian! I was thinking more … space dragons with “lasers”',
#  '@PPathole Alternate name for our company was Faraday, who invented the electric motor, whereas Nikola Tesla invented the AC induction motor',
#  '@SpacePadreIsle In a way, this is free QA haha',
#  '@teslaownersSV A beautiful home for life',
#  '@SpacePadreIsle Some Starlink terminals near conflict areas were being jammed for several hours at a time. Our latest software update bypasses the jamming.\n\nAm curious to see what’s next!',
#  '@RationalEtienne @RogerYar Exactly',
#  '@RogerYar All news sources are partially propaganda, some more than others',
#  'Starlink has been told by some governments (not Ukraine) to block Russian news sources. We will not do so unless at gunpoint.\n\nSorry to be a free speech absolutist.',
#  'SpaceX reprioritized to cyber defense &amp; overcoming signal jamming. \n\nWill cause slight delays in Starship &amp; Starlink V2.']

# %% [markdown]
# # **Creating DataFrames**

# %%
df = pd.DataFrame({'tweets':tweets,'likes':likes,'time':time})

# %%
df
# Out:
#                                                tweets   likes  \
# 0   @wintonARK @pmarca ESG should be deleted if no...    2295
# 1     @pmarca ESG rules have been twisted to insanity    8908
# 2            @SpaceX Another Starlink launch tomorrow   33116
# 3   You are my favorite hello,\nAnd my hardest goo...  322478
# 4   @hiromichimizuno @GailAlfarATX @Tesla @TeslaSo...    7083
# 5   @GailAlfarATX @Tesla @TeslaSolar @japan @vigol...    6995
# 6   RT @Tesla: Giga Berlin darf eröffnen 🇩🇪🚘 \n\nC...       0
# 7   Also nuclear is vastly better for global warmi...  158551
# 8   For those who (mistakenly) think this is a rad...  166684
# 9   Hopefully, it is now extremely obvious that Eu...  304644
# 10  @RenataKonkoly @Rainmaker1973 Aquarion and Pol...    1835
# 11  Self-driving car will amplify traffic to insan...   90802
# 12                               @MilMileBattery Yeah    2666
# 13                                       @BLKMDL3 Yup    5607
# 14  Defeating traffic is the ultimate boss battle....  184062
# 15                   @OwenSparks_ @Tesla @POTUS Cool!   14240
# 16  @Rainmaker1973 Polytopia is *way* better imo, ...    6407
# 17  @Rainmaker1973 Chess is a simple game. Underst...    8559
# 18                          @PPathole .@boringcompany    3155
# 19                                        @PPathole 💯   11532
# 20  @drbarnard @GE_Appliances Basic appliances sho...   12870
# 21  @BillyM2k @OfficialABQ Maybe Tesla should make...   17681
# 22  @ICannot_Enough Beta 10.12 probably releases T...    4659
# 23  @BronxViking718 Terminator Resistance is a goo...    8667
# 24  Even some of the best AI software engineers in...  251554
# 25  @ICannot_Enough We are almost at the point whe...    8192
# 26                            https://t.co/UrldeBBwEc  346297
# 27  @ChristianWalk1r Increased oil &amp; gas produ...   39475
# 28  @teslaownersSV @SpaceX @NASA To be clear, Spac...   19949
# 29   @teslaownersSV @SpaceX @NASA My old delta-v mug!   14362
# 30                                     @OfficialABQ 💯   43663
# 31  @TheBabylonBee Pshaw, how pedestrian! I was th...   39203
# 32  @PPathole Alternate name for our company was F...   19164
# 33     @SpacePadreIsle In a way, this is free QA haha   13094
# 34           @teslaownersSV A beautiful home for life   24138
# 35  @SpacePadreIsle Some Starlink terminals near c...   26034
# 36                 @RationalEtienne @RogerYar Exactly    6981
# 37  @RogerYar All news sources are partially propa...   66741
# 38  Starlink has been told by some governments (no...  545773
# 39  SpaceX reprioritized to cyber defense &amp; ov...  149957
#
#                   time
# 0  2022-03-08 18:26:28
# 1  2022-03-08 13:54:58
# 2  2022-03-07 20:44:40
# 3  2022-03-07 07:49:42
# 4  2022-03-07 07:08:48
# 5  2022-03-07 00:51:04
# 6  2022-03-06 23:59:10
# 7  2022-03-06 23:57:02
# 8  2022-03-06 23:33:20
# 9  2022-03-06 23:27:00
# 10 2022-03-06 14:19:34
# 11 2022-03-06 14:18:02
# 12 2022-03-06 14:13:41
# 13 2022-03-06 14:10:11
# 14 2022-03-06 14:06:26
# 15 2022-03-06 13:59:18
# 16 2022-03-06 13:57:37
# 17 2022-03-06 13:55:07
# 18 2022-03-06 13:51:57
# 19 2022-03-06 13:46:32
# 20 2022-03-06 12:15:40
# 21 2022-03-06 05:27:17
# 22 2022-03-06 05:02:50
# 23 2022-03-06 04:44:14
# 24 2022-03-06 04:38:57
# 25 2022-03-06 04:36:35
# 26 2022-03-06 03:45:50
# 27 2022-03-05 21:12:57
# 28 2022-03-05 19:49:28
# 29 2022-03-05 19:33:41
# 30 2022-03-05 18:40:56
# 31 2022-03-05 18:23:51
# 32 2022-03-05 13:17:09
# 33 2022-03-05 08:47:21
# 34 2022-03-05 08:40:13
# 35 2022-03-05 08:32:12
# 36 2022-03-05 07:28:25
# 37 2022-03-05 05:39:29
# 38 2022-03-05 05:15:51
# 39 2022-03-05 04:59:24

# %% [markdown]
# # **Remove Retweets**

# %%
df = df[~df.tweets.str.contains("RT")]

# %%
df=df.reset_index(drop=True)

# %%
df
# Out:
#                                                tweets   likes  \
# 0   @wintonARK @pmarca ESG should be deleted if no...    2295
# 1     @pmarca ESG rules have been twisted to insanity    8908
# 2            @SpaceX Another Starlink launch tomorrow   33116
# 3   You are my favorite hello,\nAnd my hardest goo...  322478
# 4   @hiromichimizuno @GailAlfarATX @Tesla @TeslaSo...    7083
# 5   @GailAlfarATX @Tesla @TeslaSolar @japan @vigol...    6995
# 6   Also nuclear is vastly better for global warmi...  158551
# 7   For those who (mistakenly) think this is a rad...  166684
# 8   Hopefully, it is now extremely obvious that Eu...  304644
# 9   @RenataKonkoly @Rainmaker1973 Aquarion and Pol...    1835
# 10  Self-driving car will amplify traffic to insan...   90802
# 11                               @MilMileBattery Yeah    2666
# 12                                       @BLKMDL3 Yup    5607
# 13  Defeating traffic is the ultimate boss battle....  184062
# 14                   @OwenSparks_ @Tesla @POTUS Cool!   14240
# 15  @Rainmaker1973 Polytopia is *way* better imo, ...    6407
# 16  @Rainmaker1973 Chess is a simple game. Underst...    8559
# 17                          @PPathole .@boringcompany    3155
# 18                                        @PPathole 💯   11532
# 19  @drbarnard @GE_Appliances Basic appliances sho...   12870
# 20  @BillyM2k @OfficialABQ Maybe Tesla should make...   17681
# 21  @ICannot_Enough Beta 10.12 probably releases T...    4659
# 22  @BronxViking718 Terminator Resistance is a goo...    8667
# 23  Even some of the best AI software engineers in...  251554
# 24  @ICannot_Enough We are almost at the point whe...    8192
# 25                            https://t.co/UrldeBBwEc  346297
# 26  @ChristianWalk1r Increased oil &amp; gas produ...   39475
# 27  @teslaownersSV @SpaceX @NASA To be clear, Spac...   19949
# 28   @teslaownersSV @SpaceX @NASA My old delta-v mug!   14362
# 29                                     @OfficialABQ 💯   43663
# 30  @TheBabylonBee Pshaw, how pedestrian! I was th...   39203
# 31  @PPathole Alternate name for our company was F...   19164
# 32     @SpacePadreIsle In a way, this is free QA haha   13094
# 33           @teslaownersSV A beautiful home for life   24138
# 34  @SpacePadreIsle Some Starlink terminals near c...   26034
# 35                 @RationalEtienne @RogerYar Exactly    6981
# 36  @RogerYar All news sources are partially propa...   66741
# 37  Starlink has been told by some governments (no...  545773
# 38  SpaceX reprioritized to cyber defense &amp; ov...  149957
#
#                   time
# 0  2022-03-08 18:26:28
# 1  2022-03-08 13:54:58
# 2  2022-03-07 20:44:40
# 3  2022-03-07 07:49:42
# 4  2022-03-07 07:08:48
# 5  2022-03-07 00:51:04
# 6  2022-03-06 23:57:02
# 7  2022-03-06 23:33:20
# 8  2022-03-06 23:27:00
# 9  2022-03-06 14:19:34
# 10 2022-03-06 14:18:02
# 11 2022-03-06 14:13:41
# 12 2022-03-06 14:10:11
# 13 2022-03-06 14:06:26
# 14 2022-03-06 13:59:18
# 15 2022-03-06 13:57:37
# 16 2022-03-06 13:55:07
# 17 2022-03-06 13:51:57
# 18 2022-03-06 13:46:32
# 19 2022-03-06 12:15:40
# 20 2022-03-06 05:27:17
# 21 2022-03-06 05:02:50
# 22 2022-03-06 04:44:14
# 23 2022-03-06 04:38:57
# 24 2022-03-06 04:36:35
# 25 2022-03-06 03:45:50
# 26 2022-03-05 21:12:57
# 27 2022-03-05 19:49:28
# 28 2022-03-05 19:33:41
# 29 2022-03-05 18:40:56
# 30 2022-03-05 18:23:51
# 31 2022-03-05 13:17:09
# 32 2022-03-05 08:47:21
# 33 2022-03-05 08:40:13
# 34 2022-03-05 08:32:12
# 35 2022-03-05 07:28:25
# 36 2022-03-05 05:39:29
# 37 2022-03-05 05:15:51
# 38 2022-03-05 04:59:24

# %% [markdown]
# **most liked tweets**

# %%
mostlike = df.loc[df.likes.nlargest(5).index]

# %%
mostlike
# Out:
#                                                tweets   likes  \
# 37  Starlink has been told by some governments (no...  545773
# 25                            https://t.co/UrldeBBwEc  346297
# 3   You are my favorite hello,\nAnd my hardest goo...  322478
# 8   Hopefully, it is now extremely obvious that Eu...  304644
# 23  Even some of the best AI software engineers in...  251554
#
#                   time
# 37 2022-03-05 05:15:51
# 25 2022-03-06 03:45:50
# 3  2022-03-07 07:49:42
# 8  2022-03-06 23:27:00
# 23 2022-03-06 04:38:57

# %%
import matplotlib.pyplot as plt
import re
import spacy.cli
spacy.cli.download("en_core_web_lg")
nlp = spacy.load('en_core_web_lg')
import seaborn as sns
# Out:
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_lg')

# %%
list_of_sentences = [sentence for sentence in df.tweets]

lines = []
for sentence in list_of_sentences:
  words = sentence.split()
  for w in words:
    lines.append(w)

# %% [markdown]
# # **Removing Special Characters**

# %%
for i in range(len(lines)):
    lines[i] = lines[i].lower()
lines = [re.sub(r'[^A-Za-z0-9]+','',x) for x in lines]

lines2 = []

for word in lines:
  if word != '':
    lines2.append(word)

# %%
from nltk.stem.snowball import SnowballStemmer

s_stemmer = SnowballStemmer(language = 'english')
stem = []
for word in lines2:
  stem.append(s_stemmer.stem(word))

# %%
stem2 = []
for word in stem:
  if word not in nlp.Defaults.stop_words:
    stem2.append(word)

# %%
df2 = pd.DataFrame(stem2)
df2 = df2[0].value_counts()

# %% [markdown]
# # **Plotting Graph for most used words**

# %%
df2 = df2[:20,]
plt.figure(figsize=(10,5))
sns.barplot(df2.values, df2.index, alpha=1)
plt.title('Top words Overall')
plt.ylabel('Word from Tweet',fontsize=12)
plt.xlabel('Count of Words',fontsize=12)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # **Top Mentioned Person name in Elon Musk tweets**

# %%
str1 = " "
stem2 = str1.join(lines2)
stem2 = nlp(stem2)
label = [(X.text, X.label_) for X in stem2.ents]
df10 = pd.DataFrame(label, columns = ['Word', 'Entity'])
df10 = df10.where(df10['Entity'] == 'PERSON')
df11 = df10['Word'].value_counts()

# %%
dfy = df11[:20,]
plt.figure(figsize=(10,5))
sns.barplot(dfy.values, dfy.index, alpha=1)
plt.title('Top people mentioned')
plt.ylabel('Word from Tweet',fontsize=12)
plt.xlabel('Count of Words',fontsize=12)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
